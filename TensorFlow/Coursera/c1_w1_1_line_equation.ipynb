# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshChopra/AI-ML/blob/master/TensorFlow/Coursera/c1_w1_1_line_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem: Line Equation Y = 2x + 1
#
#
# ## Import required Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Define Dataset

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# ## Explore Dataset

# %%
xs
# Out:
# array([-1.,  0.,  1.,  2.,  3.,  4.])

# %%
ys
# Out:
# array([-3., -1.,  1.,  3.,  5.,  7.])

# %% [markdown]
# ## Create Model

# %%
model = tf.keras.Sequential([
      keras.layers.Dense(1, input_shape=[1])
])

# %% [markdown]
# ## Compile Model

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Train Model

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1378
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1350
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1322
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1295
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1269
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1243
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1217
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1192
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1168
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1144
# Epoch 11/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1120
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1097
# ...

# %% [markdown]
# ## Predict Value

# %%
print(model.predict([10.0]))
# Out:
# [[18.993893]]
