# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshChopra/AI-ML/blob/master/TensorFlow/Coursera/c1_w1_lab2_multi_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build a Multi Output Model

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat

# %%
def format_output(data):
  y1 = data.pop('Y1')
  y1 = np.array(y1)
  y2 = data.pop('Y2')
  y2 = np.array(y2)
  return y1, y2

def norm(x):
  return (x - train_stats['mean']) / train_stats['std']

def plot_diff(y_true, y_pred, title=''):
  plt.scatter(y_true, y_pred)
  plt.title(title)
  plt.xlabel('True Values')
  plt.ylabel('Predictions')
  plt.axis('equal')
  plt.axis('square')
  plt.xlim(plt.xlim())
  plt.ylim(plt.ylim())
  plt.plot([-100, 100], [-100, 100])
  plt.show()

def plot_metrics(metric_name, title, ylim=5):
  plt.title(title)
  plt.ylim(0, ylim)
  plt.plot(history.history[metric_name], color='blue', label=metric_name)
  plt.plot(history.history['val_' + metric_name], color='green', label='val_'+metric_name)
  plt.show()

# %% [markdown]
# ## Prepare the data
#
# Download the dataset and format it for training

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
# Here is how we'll build the model using hte functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure Parameters
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, 
                    validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 5ms/step - loss: 591.4383 - y1_output_loss: 271.6920 - y2_output_loss: 319.7463 - y1_output_root_mean_squared_error: 15.9186 - y2_output_root_mean_squared_error: 17.2296 - val_loss: 35.2424 - val_y1_output_loss: 12.2551 - val_y2_output_loss: 22.9873 - val_y1_output_root_mean_squared_error: 3.5007 - val_y2_output_root_mean_squared_error: 4.7945
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 38.4423 - y1_output_loss: 14.3888 - y2_output_loss: 24.0535 - y1_output_root_mean_squared_error: 3.7810 - y2_output_root_mean_squared_error: 4.9001 - val_loss: 22.4796 - val_y1_output_loss: 9.6613 - val_y2_output_loss: 12.8182 - val_y1_output_root_mean_squared_error: 3.1083 - val_y2_output_root_mean_squared_error: 3.5803
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.8315 - y1_output_loss: 9.9989 - y2_output_loss: 13.8326 - y1_output_root_mean_squared_error: 3.1563 - y2_output_root_mean_squared_error: 3.7135 - val_loss: 21.9626 - val_y1_output_loss: 9.8819 - val_y2_output_loss: 12.0808 - val_y1_output_root_mean_squared_error: 3.1435 - val_y2_output_root_mean_squared_error: 3.4757
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.9277 - y1_output_loss: 9.2231 - y2_output_loss: 13.7046 - y1_output_root_mean_squared_error: 3.0315 - y2_output_root_mean_squared_error: 3.6840 - val_loss: 20.2716 - val_y1_output_loss: 8.8462 - val_y2_output_loss: 11.4254 - val_y1_output_root_mean_squared_error: 2.9743 - val_y2_output_root_mean_squared_error: 3.3801
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 27.3651 - y1_output_loss: 9.9047 - y2_output_loss: 17.4603 - y1_output_root_mean_squared_error: 3.1365 - y2_output_root_mean_squared_error: 4.1647 - val_loss: 27.0958 - val_y1_output_loss: 10.3463 - val_y2_output_loss: 16.7495 - val_y1_output_root_mean_squared_error: 3.2166 - val_y2_output_root_mean_squared_error: 4.0926
# Epoch 6/500
# 62/62 [==============================] - 0s 5ms/step - loss: 23.2916 - y1_output_loss: 9.6826 - y2_output_loss: 13.6090 - y1_output_root_mean_squared_error: 3.1089 - y2_output_root_mean_squared_error: 3.6795 - val_loss: 21.1068 - val_y1_output_loss: 7.2487 - val_y2_output_loss: 13.8582 - val_y1_output_root_mean_squared_error: 2.6923 - val_y2_output_root_mean_squared_error: 3.7227
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.6001 - y1_output_loss: 8.8740 - y2_output_loss: 11.7261 - y1_output_root_mean_squared_error: 2.9686 - y2_output_root_mean_squared_error: 3.4201 - val_loss: 21.7951 - val_y1_output_loss: 8.4901 - val_y2_output_loss: 13.3051 - val_y1_output_root_mean_squared_error: 2.9138 - val_y2_output_root_mean_squared_error: 3.6476
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.2456 - y1_output_loss: 7.5946 - y2_output_loss: 11.6510 - y1_output_root_mean_squared_error: 2.7488 - y2_output_root_mean_squared_error: 3.4027 - val_loss: 54.1344 - val_y1_output_loss: 13.5027 - val_y2_output_loss: 40.6317 - val_y1_output_root_mean_squared_error: 3.6746 - val_y2_output_root_mean_squared_error: 6.3743
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 34.4904 - y1_output_loss: 12.3936 - y2_output_loss: 22.0968 - y1_output_root_mean_squared_error: 3.4814 - y2_output_root_mean_squared_error: 4.5831 - val_loss: 18.5240 - val_y1_output_loss: 7.1005 - val_y2_output_loss: 11.4235 - val_y1_output_root_mean_squared_error: 2.6647 - val_y2_output_root_mean_squared_error: 3.3799
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.8957 - y1_output_loss: 7.3001 - y2_output_loss: 10.5956 - y1_output_root_mean_squared_error: 2.6971 - y2_output_root_mean_squared_error: 3.2444 - val_loss: 17.2236 - val_y1_output_loss: 7.7061 - val_y2_output_loss: 9.5175 - val_y1_output_root_mean_squared_error: 2.7760 - val_y2_output_root_mean_squared_error: 3.0850
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.9441 - y1_output_loss: 7.9219 - y2_output_loss: 11.0222 - y1_output_root_mean_squared_error: 2.8132 - y2_output_root_mean_squared_error: 3.3113 - val_loss: 17.9099 - val_y1_output_loss: 7.3489 - val_y2_output_loss: 10.5610 - val_y1_output_root_mean_squared_error: 2.7109 - val_y2_output_root_mean_squared_error: 3.2498
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.9074 - y1_output_loss: 7.9515 - y2_output_loss: 11.9559 - y1_output_root_mean_squared_error: 2.8163 - y2_output_root_mean_squared_error: 3.4438 - val_loss: 19.6576 - val_y1_output_loss: 7.9694 - val_y2_output_loss: 11.6882 - val_y1_output_root_mean_squared_error: 2.8230 - val_y2_output_root_mean_squared_error: 3.4188
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.1492 - y1_output_loss: 8.6460 - y2_output_loss: 15.5032 - y1_output_root_mean_squared_error: 2.9380 - y2_output_root_mean_squared_error: 3.9299 - val_loss: 17.9006 - val_y1_output_loss: 6.7606 - val_y2_output_loss: 11.1399 - val_y1_output_root_mean_squared_error: 2.6001 - val_y2_output_root_mean_squared_error: 3.3377
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.3523 - y1_output_loss: 6.4255 - y2_output_loss: 8.9268 - y1_output_root_mean_squared_error: 2.5327 - y2_output_root_mean_squared_error: 2.9850 - val_loss: 24.9284 - val_y1_output_loss: 6.4163 - val_y2_output_loss: 18.5121 - val_y1_output_root_mean_squared_error: 2.5331 - val_y2_output_root_mean_squared_error: 4.3026
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.7242 - y1_output_loss: 6.4320 - y2_output_loss: 10.2922 - y1_output_root_mean_squared_error: 2.5342 - y2_output_root_mean_squared_error: 3.1962 - val_loss: 36.8089 - val_y1_output_loss: 9.4479 - val_y2_output_loss: 27.3610 - val_y1_output_root_mean_squared_error: 3.0737 - val_y2_output_root_mean_squared_error: 5.2308
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.8166 - y1_output_loss: 7.3507 - y2_output_loss: 11.4659 - y1_output_root_mean_squared_error: 2.6978 - y2_output_root_mean_squared_error: 3.3576 - val_loss: 12.7434 - val_y1_output_loss: 5.4382 - val_y2_output_loss: 7.3052 - val_y1_output_root_mean_squared_error: 2.3320 - val_y2_output_root_mean_squared_error: 2.7028
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4561 - y1_output_loss: 6.0545 - y2_output_loss: 9.4016 - y1_output_root_mean_squared_error: 2.4591 - y2_output_root_mean_squared_error: 3.0626 - val_loss: 14.6070 - val_y1_output_loss: 6.2917 - val_y2_output_loss: 8.3153 - val_y1_output_root_mean_squared_error: 2.5083 - val_y2_output_root_mean_squared_error: 2.8836
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.1467 - y1_output_loss: 5.8894 - y2_output_loss: 8.2572 - y1_output_root_mean_squared_error: 2.4196 - y2_output_root_mean_squared_error: 2.8688 - val_loss: 12.3959 - val_y1_output_loss: 5.2214 - val_y2_output_loss: 7.1745 - val_y1_output_root_mean_squared_error: 2.2850 - val_y2_output_root_mean_squared_error: 2.6785
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.4630 - y1_output_loss: 5.5897 - y2_output_loss: 8.8733 - y1_output_root_mean_squared_error: 2.3597 - y2_output_root_mean_squared_error: 2.9719 - val_loss: 14.7123 - val_y1_output_loss: 5.8221 - val_y2_output_loss: 8.8902 - val_y1_output_root_mean_squared_error: 2.4129 - val_y2_output_root_mean_squared_error: 2.9816
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.6421 - y1_output_loss: 6.6997 - y2_output_loss: 10.9424 - y1_output_root_mean_squared_error: 2.5818 - y2_output_root_mean_squared_error: 3.2977 - val_loss: 13.3840 - val_y1_output_loss: 4.7402 - val_y2_output_loss: 8.6438 - val_y1_output_root_mean_squared_error: 2.1772 - val_y2_output_root_mean_squared_error: 2.9400
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.7554 - y1_output_loss: 5.4709 - y2_output_loss: 9.2844 - y1_output_root_mean_squared_error: 2.3335 - y2_output_root_mean_squared_error: 3.0316 - val_loss: 16.6929 - val_y1_output_loss: 6.2368 - val_y2_output_loss: 10.4561 - val_y1_output_root_mean_squared_error: 2.4974 - val_y2_output_root_mean_squared_error: 3.2336
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.4016 - y1_output_loss: 4.6363 - y2_output_loss: 8.7653 - y1_output_root_mean_squared_error: 2.1500 - y2_output_root_mean_squared_error: 2.9560 - val_loss: 11.4881 - val_y1_output_loss: 4.8482 - val_y2_output_loss: 6.6399 - val_y1_output_root_mean_squared_error: 2.2019 - val_y2_output_root_mean_squared_error: 2.5768
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.9421 - y1_output_loss: 4.8918 - y2_output_loss: 9.0503 - y1_output_root_mean_squared_error: 2.2100 - y2_output_root_mean_squared_error: 3.0018 - val_loss: 9.3303 - val_y1_output_loss: 4.0071 - val_y2_output_loss: 5.3232 - val_y1_output_root_mean_squared_error: 2.0018 - val_y2_output_root_mean_squared_error: 2.3072
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.7391 - y1_output_loss: 5.7049 - y2_output_loss: 12.0341 - y1_output_root_mean_squared_error: 2.3870 - y2_output_root_mean_squared_error: 3.4612 - val_loss: 9.9472 - val_y1_output_loss: 4.3565 - val_y2_output_loss: 5.5907 - val_y1_output_root_mean_squared_error: 2.0872 - val_y2_output_root_mean_squared_error: 2.3645
# Epoch 25/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.4718 - y1_output_loss: 4.1037 - y2_output_loss: 7.3681 - y1_output_root_mean_squared_error: 2.0228 - y2_output_root_mean_squared_error: 2.6968 - val_loss: 22.7081 - val_y1_output_loss: 7.2264 - val_y2_output_loss: 15.4817 - val_y1_output_root_mean_squared_error: 2.6882 - val_y2_output_root_mean_squared_error: 3.9347
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.2884 - y1_output_loss: 4.7917 - y2_output_loss: 8.4967 - y1_output_root_mean_squared_error: 2.1871 - y2_output_root_mean_squared_error: 2.9072 - val_loss: 8.7601 - val_y1_output_loss: 3.8139 - val_y2_output_loss: 4.9462 - val_y1_output_root_mean_squared_error: 1.9529 - val_y2_output_root_mean_squared_error: 2.2240
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.1627 - y1_output_loss: 3.8599 - y2_output_loss: 7.3028 - y1_output_root_mean_squared_error: 1.9631 - y2_output_root_mean_squared_error: 2.6957 - val_loss: 12.9830 - val_y1_output_loss: 6.1194 - val_y2_output_loss: 6.8636 - val_y1_output_root_mean_squared_error: 2.4737 - val_y2_output_root_mean_squared_error: 2.6199
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.2993 - y1_output_loss: 3.6586 - y2_output_loss: 7.6407 - y1_output_root_mean_squared_error: 1.9061 - y2_output_root_mean_squared_error: 2.7564 - val_loss: 8.7423 - val_y1_output_loss: 3.8334 - val_y2_output_loss: 4.9089 - val_y1_output_root_mean_squared_error: 1.9579 - val_y2_output_root_mean_squared_error: 2.2156
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.0562 - y1_output_loss: 3.2983 - y2_output_loss: 6.7579 - y1_output_root_mean_squared_error: 1.8041 - y2_output_root_mean_squared_error: 2.5882 - val_loss: 10.6660 - val_y1_output_loss: 3.0081 - val_y2_output_loss: 7.6579 - val_y1_output_root_mean_squared_error: 1.7344 - val_y2_output_root_mean_squared_error: 2.7673
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.3201 - y1_output_loss: 4.4464 - y2_output_loss: 7.8738 - y1_output_root_mean_squared_error: 2.1036 - y2_output_root_mean_squared_error: 2.7941 - val_loss: 35.9645 - val_y1_output_loss: 8.1585 - val_y2_output_loss: 27.8060 - val_y1_output_root_mean_squared_error: 2.8563 - val_y2_output_root_mean_squared_error: 5.2731
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.4241 - y1_output_loss: 4.1338 - y2_output_loss: 8.2903 - y1_output_root_mean_squared_error: 2.0214 - y2_output_root_mean_squared_error: 2.8683 - val_loss: 7.0506 - val_y1_output_loss: 2.7536 - val_y2_output_loss: 4.2970 - val_y1_output_root_mean_squared_error: 1.6594 - val_y2_output_root_mean_squared_error: 2.0729
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.0237 - y1_output_loss: 3.5309 - y2_output_loss: 6.4928 - y1_output_root_mean_squared_error: 1.8774 - y2_output_root_mean_squared_error: 2.5361 - val_loss: 7.7717 - val_y1_output_loss: 2.5373 - val_y2_output_loss: 5.2344 - val_y1_output_root_mean_squared_error: 1.5929 - val_y2_output_root_mean_squared_error: 2.2879
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.1374 - y1_output_loss: 3.2768 - y2_output_loss: 7.8606 - y1_output_root_mean_squared_error: 1.8026 - y2_output_root_mean_squared_error: 2.7906 - val_loss: 13.0900 - val_y1_output_loss: 4.5460 - val_y2_output_loss: 8.5440 - val_y1_output_root_mean_squared_error: 2.1321 - val_y2_output_root_mean_squared_error: 2.9230
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2323 - y1_output_loss: 2.7411 - y2_output_loss: 5.4912 - y1_output_root_mean_squared_error: 1.6542 - y2_output_root_mean_squared_error: 2.3371 - val_loss: 15.0548 - val_y1_output_loss: 4.3928 - val_y2_output_loss: 10.6620 - val_y1_output_root_mean_squared_error: 2.0959 - val_y2_output_root_mean_squared_error: 3.2653
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.6947 - y1_output_loss: 3.2230 - y2_output_loss: 6.4717 - y1_output_root_mean_squared_error: 1.7931 - y2_output_root_mean_squared_error: 2.5427 - val_loss: 6.5773 - val_y1_output_loss: 2.6767 - val_y2_output_loss: 3.9006 - val_y1_output_root_mean_squared_error: 1.6361 - val_y2_output_root_mean_squared_error: 1.9750
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0758 - y1_output_loss: 3.0821 - y2_output_loss: 5.9937 - y1_output_root_mean_squared_error: 1.7543 - y2_output_root_mean_squared_error: 2.4452 - val_loss: 17.2526 - val_y1_output_loss: 5.7338 - val_y2_output_loss: 11.5188 - val_y1_output_root_mean_squared_error: 2.3945 - val_y2_output_root_mean_squared_error: 3.3939
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.1535 - y1_output_loss: 4.3962 - y2_output_loss: 9.7573 - y1_output_root_mean_squared_error: 2.0723 - y2_output_root_mean_squared_error: 3.0533 - val_loss: 11.8485 - val_y1_output_loss: 3.2859 - val_y2_output_loss: 8.5626 - val_y1_output_root_mean_squared_error: 1.8127 - val_y2_output_root_mean_squared_error: 2.9262
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.7682 - y1_output_loss: 2.8954 - y2_output_loss: 8.8728 - y1_output_root_mean_squared_error: 1.6965 - y2_output_root_mean_squared_error: 2.9560 - val_loss: 7.3066 - val_y1_output_loss: 2.3126 - val_y2_output_loss: 4.9940 - val_y1_output_root_mean_squared_error: 1.5207 - val_y2_output_root_mean_squared_error: 2.2347
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.0242 - y1_output_loss: 3.3066 - y2_output_loss: 6.7176 - y1_output_root_mean_squared_error: 1.8103 - y2_output_root_mean_squared_error: 2.5817 - val_loss: 7.3226 - val_y1_output_loss: 3.0348 - val_y2_output_loss: 4.2878 - val_y1_output_root_mean_squared_error: 1.7421 - val_y2_output_root_mean_squared_error: 2.0707
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.9697 - y1_output_loss: 3.2866 - y2_output_loss: 6.6831 - y1_output_root_mean_squared_error: 1.8097 - y2_output_root_mean_squared_error: 2.5807 - val_loss: 7.3483 - val_y1_output_loss: 3.1552 - val_y2_output_loss: 4.1931 - val_y1_output_root_mean_squared_error: 1.7763 - val_y2_output_root_mean_squared_error: 2.0477
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.9642 - y1_output_loss: 2.4526 - y2_output_loss: 5.5116 - y1_output_root_mean_squared_error: 1.5650 - y2_output_root_mean_squared_error: 2.3464 - val_loss: 5.8140 - val_y1_output_loss: 2.3555 - val_y2_output_loss: 3.4585 - val_y1_output_root_mean_squared_error: 1.5348 - val_y2_output_root_mean_squared_error: 1.8597
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.0359 - y1_output_loss: 2.1630 - y2_output_loss: 4.8728 - y1_output_root_mean_squared_error: 1.4692 - y2_output_root_mean_squared_error: 2.2064 - val_loss: 12.9569 - val_y1_output_loss: 2.7397 - val_y2_output_loss: 10.2172 - val_y1_output_root_mean_squared_error: 1.6552 - val_y2_output_root_mean_squared_error: 3.1964
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.7501 - y1_output_loss: 2.4318 - y2_output_loss: 6.3183 - y1_output_root_mean_squared_error: 1.5563 - y2_output_root_mean_squared_error: 2.4988 - val_loss: 5.0065 - val_y1_output_loss: 1.8652 - val_y2_output_loss: 3.1413 - val_y1_output_root_mean_squared_error: 1.3657 - val_y2_output_root_mean_squared_error: 1.7724
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.9834 - y1_output_loss: 2.4113 - y2_output_loss: 5.5722 - y1_output_root_mean_squared_error: 1.5501 - y2_output_root_mean_squared_error: 2.3580 - val_loss: 5.3934 - val_y1_output_loss: 1.9395 - val_y2_output_loss: 3.4539 - val_y1_output_root_mean_squared_error: 1.3926 - val_y2_output_root_mean_squared_error: 1.8585
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7067 - y1_output_loss: 2.1453 - y2_output_loss: 4.5614 - y1_output_root_mean_squared_error: 1.4635 - y2_output_root_mean_squared_error: 2.1323 - val_loss: 7.9919 - val_y1_output_loss: 3.2005 - val_y2_output_loss: 4.7913 - val_y1_output_root_mean_squared_error: 1.7890 - val_y2_output_root_mean_squared_error: 2.1889
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.8429 - y1_output_loss: 1.8640 - y2_output_loss: 3.9789 - y1_output_root_mean_squared_error: 1.3638 - y2_output_root_mean_squared_error: 1.9909 - val_loss: 9.2413 - val_y1_output_loss: 2.3341 - val_y2_output_loss: 6.9071 - val_y1_output_root_mean_squared_error: 1.5278 - val_y2_output_root_mean_squared_error: 2.6281
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.6109 - y1_output_loss: 2.2706 - y2_output_loss: 6.3404 - y1_output_root_mean_squared_error: 1.5008 - y2_output_root_mean_squared_error: 2.5137 - val_loss: 42.0221 - val_y1_output_loss: 10.7051 - val_y2_output_loss: 31.3170 - val_y1_output_root_mean_squared_error: 3.2719 - val_y2_output_root_mean_squared_error: 5.5962
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2789 - y1_output_loss: 2.8407 - y2_output_loss: 5.4382 - y1_output_root_mean_squared_error: 1.6776 - y2_output_root_mean_squared_error: 2.3167 - val_loss: 6.8757 - val_y1_output_loss: 2.0228 - val_y2_output_loss: 4.8529 - val_y1_output_root_mean_squared_error: 1.4222 - val_y2_output_root_mean_squared_error: 2.2029
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.5608 - y1_output_loss: 2.7461 - y2_output_loss: 7.8147 - y1_output_root_mean_squared_error: 1.6546 - y2_output_root_mean_squared_error: 2.7801 - val_loss: 6.9240 - val_y1_output_loss: 2.0042 - val_y2_output_loss: 4.9198 - val_y1_output_root_mean_squared_error: 1.4157 - val_y2_output_root_mean_squared_error: 2.2181
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.4293 - y1_output_loss: 2.0000 - y2_output_loss: 4.4292 - y1_output_root_mean_squared_error: 1.4129 - y2_output_root_mean_squared_error: 2.0994 - val_loss: 7.3635 - val_y1_output_loss: 3.0084 - val_y2_output_loss: 4.3551 - val_y1_output_root_mean_squared_error: 1.7345 - val_y2_output_root_mean_squared_error: 2.0869
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.2836 - y1_output_loss: 2.0094 - y2_output_loss: 4.2742 - y1_output_root_mean_squared_error: 1.4074 - y2_output_root_mean_squared_error: 2.0628 - val_loss: 4.5505 - val_y1_output_loss: 1.4232 - val_y2_output_loss: 3.1273 - val_y1_output_root_mean_squared_error: 1.1930 - val_y2_output_root_mean_squared_error: 1.7684
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.8824 - y1_output_loss: 2.8507 - y2_output_loss: 6.0318 - y1_output_root_mean_squared_error: 1.6676 - y2_output_root_mean_squared_error: 2.4313 - val_loss: 54.6217 - val_y1_output_loss: 18.3451 - val_y2_output_loss: 36.2766 - val_y1_output_root_mean_squared_error: 4.2831 - val_y2_output_root_mean_squared_error: 6.0230
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.8484 - y1_output_loss: 3.7986 - y2_output_loss: 8.0498 - y1_output_root_mean_squared_error: 1.8531 - y2_output_root_mean_squared_error: 2.7506 - val_loss: 5.0293 - val_y1_output_loss: 1.8691 - val_y2_output_loss: 3.1601 - val_y1_output_root_mean_squared_error: 1.3672 - val_y2_output_root_mean_squared_error: 1.7777
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.2761 - y1_output_loss: 1.8570 - y2_output_loss: 4.4191 - y1_output_root_mean_squared_error: 1.3592 - y2_output_root_mean_squared_error: 2.0987 - val_loss: 4.6683 - val_y1_output_loss: 1.4806 - val_y2_output_loss: 3.1877 - val_y1_output_root_mean_squared_error: 1.2168 - val_y2_output_root_mean_squared_error: 1.7854
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6495 - y1_output_loss: 1.4584 - y2_output_loss: 4.1911 - y1_output_root_mean_squared_error: 1.2027 - y2_output_root_mean_squared_error: 2.0445 - val_loss: 9.2297 - val_y1_output_loss: 2.1053 - val_y2_output_loss: 7.1244 - val_y1_output_root_mean_squared_error: 1.4510 - val_y2_output_root_mean_squared_error: 2.6692
# Epoch 56/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1044 - y1_output_loss: 1.8271 - y2_output_loss: 4.2773 - y1_output_root_mean_squared_error: 1.3486 - y2_output_root_mean_squared_error: 2.0586 - val_loss: 7.4426 - val_y1_output_loss: 2.4740 - val_y2_output_loss: 4.9685 - val_y1_output_root_mean_squared_error: 1.5729 - val_y2_output_root_mean_squared_error: 2.2290
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4299 - y1_output_loss: 1.3558 - y2_output_loss: 3.0742 - y1_output_root_mean_squared_error: 1.1628 - y2_output_root_mean_squared_error: 1.7468 - val_loss: 8.6204 - val_y1_output_loss: 1.9976 - val_y2_output_loss: 6.6228 - val_y1_output_root_mean_squared_error: 1.4134 - val_y2_output_root_mean_squared_error: 2.5735
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.4043 - y1_output_loss: 1.6920 - y2_output_loss: 4.7123 - y1_output_root_mean_squared_error: 1.2966 - y2_output_root_mean_squared_error: 2.1555 - val_loss: 10.4449 - val_y1_output_loss: 2.6682 - val_y2_output_loss: 7.7767 - val_y1_output_root_mean_squared_error: 1.6335 - val_y2_output_root_mean_squared_error: 2.7887
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1769 - y1_output_loss: 1.4083 - y2_output_loss: 4.7686 - y1_output_root_mean_squared_error: 1.1782 - y2_output_root_mean_squared_error: 2.1564 - val_loss: 6.3878 - val_y1_output_loss: 2.0478 - val_y2_output_loss: 4.3400 - val_y1_output_root_mean_squared_error: 1.4310 - val_y2_output_root_mean_squared_error: 2.0833
# Epoch 60/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8152 - y1_output_loss: 2.4119 - y2_output_loss: 5.4033 - y1_output_root_mean_squared_error: 1.5450 - y2_output_root_mean_squared_error: 2.3171 - val_loss: 9.5741 - val_y1_output_loss: 1.8859 - val_y2_output_loss: 7.6882 - val_y1_output_root_mean_squared_error: 1.3733 - val_y2_output_root_mean_squared_error: 2.7728
# Epoch 61/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.6343 - y1_output_loss: 4.9645 - y2_output_loss: 10.6698 - y1_output_root_mean_squared_error: 2.1386 - y2_output_root_mean_squared_error: 3.1439 - val_loss: 3.4339 - val_y1_output_loss: 0.9861 - val_y2_output_loss: 2.4478 - val_y1_output_root_mean_squared_error: 0.9930 - val_y2_output_root_mean_squared_error: 1.5645
# Epoch 62/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.9101 - y1_output_loss: 1.2463 - y2_output_loss: 3.6638 - y1_output_root_mean_squared_error: 1.1067 - y2_output_root_mean_squared_error: 1.9004 - val_loss: 7.9609 - val_y1_output_loss: 1.5967 - val_y2_output_loss: 6.3642 - val_y1_output_root_mean_squared_error: 1.2636 - val_y2_output_root_mean_squared_error: 2.5227
# Epoch 63/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.9131 - y1_output_loss: 1.1620 - y2_output_loss: 3.7511 - y1_output_root_mean_squared_error: 1.0756 - y2_output_root_mean_squared_error: 1.9322 - val_loss: 2.9878 - val_y1_output_loss: 0.8431 - val_y2_output_loss: 2.1446 - val_y1_output_root_mean_squared_error: 0.9182 - val_y2_output_root_mean_squared_error: 1.4645
# Epoch 64/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.1560 - y1_output_loss: 1.0388 - y2_output_loss: 3.1172 - y1_output_root_mean_squared_error: 1.0159 - y2_output_root_mean_squared_error: 1.7636 - val_loss: 5.0379 - val_y1_output_loss: 1.2388 - val_y2_output_loss: 3.7991 - val_y1_output_root_mean_squared_error: 1.1130 - val_y2_output_root_mean_squared_error: 1.9491
# Epoch 65/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2793 - y1_output_loss: 1.5301 - y2_output_loss: 3.7491 - y1_output_root_mean_squared_error: 1.2272 - y2_output_root_mean_squared_error: 1.9330 - val_loss: 8.8555 - val_y1_output_loss: 1.4154 - val_y2_output_loss: 7.4401 - val_y1_output_root_mean_squared_error: 1.1897 - val_y2_output_root_mean_squared_error: 2.7277
# Epoch 66/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.0287 - y1_output_loss: 2.6770 - y2_output_loss: 7.3517 - y1_output_root_mean_squared_error: 1.6068 - y2_output_root_mean_squared_error: 2.6573 - val_loss: 5.3312 - val_y1_output_loss: 0.9709 - val_y2_output_loss: 4.3603 - val_y1_output_root_mean_squared_error: 0.9854 - val_y2_output_root_mean_squared_error: 2.0881
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.0074 - y1_output_loss: 2.1452 - y2_output_loss: 5.8622 - y1_output_root_mean_squared_error: 1.4493 - y2_output_root_mean_squared_error: 2.3905 - val_loss: 3.0235 - val_y1_output_loss: 0.8521 - val_y2_output_loss: 2.1713 - val_y1_output_root_mean_squared_error: 0.9231 - val_y2_output_root_mean_squared_error: 1.4735
# Epoch 68/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.9903 - y1_output_loss: 0.8840 - y2_output_loss: 3.1063 - y1_output_root_mean_squared_error: 0.9394 - y2_output_root_mean_squared_error: 1.7614 - val_loss: 54.4914 - val_y1_output_loss: 17.2590 - val_y2_output_loss: 37.2324 - val_y1_output_root_mean_squared_error: 4.1544 - val_y2_output_root_mean_squared_error: 6.1018
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.7187 - y1_output_loss: 4.4402 - y2_output_loss: 9.2785 - y1_output_root_mean_squared_error: 1.9905 - y2_output_root_mean_squared_error: 2.8987 - val_loss: 10.9537 - val_y1_output_loss: 1.8733 - val_y2_output_loss: 9.0804 - val_y1_output_root_mean_squared_error: 1.3687 - val_y2_output_root_mean_squared_error: 3.0134
# Epoch 70/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.5813 - y1_output_loss: 1.1835 - y2_output_loss: 4.3978 - y1_output_root_mean_squared_error: 1.0850 - y2_output_root_mean_squared_error: 2.0848 - val_loss: 2.7181 - val_y1_output_loss: 0.7109 - val_y2_output_loss: 2.0072 - val_y1_output_root_mean_squared_error: 0.8431 - val_y2_output_root_mean_squared_error: 1.4168
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.1630 - y1_output_loss: 1.0764 - y2_output_loss: 3.0866 - y1_output_root_mean_squared_error: 1.0322 - y2_output_root_mean_squared_error: 1.7489 - val_loss: 4.0374 - val_y1_output_loss: 0.6140 - val_y2_output_loss: 3.4233 - val_y1_output_root_mean_squared_error: 0.7836 - val_y2_output_root_mean_squared_error: 1.8502
# Epoch 72/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7022 - y1_output_loss: 0.7215 - y2_output_loss: 2.9806 - y1_output_root_mean_squared_error: 0.8489 - y2_output_root_mean_squared_error: 1.7256 - val_loss: 3.1740 - val_y1_output_loss: 0.6796 - val_y2_output_loss: 2.4944 - val_y1_output_root_mean_squared_error: 0.8244 - val_y2_output_root_mean_squared_error: 1.5794
# Epoch 73/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.4423 - y1_output_loss: 2.5885 - y2_output_loss: 4.8538 - y1_output_root_mean_squared_error: 1.5614 - y2_output_root_mean_squared_error: 2.1703 - val_loss: 2.6264 - val_y1_output_loss: 0.6769 - val_y2_output_loss: 1.9495 - val_y1_output_root_mean_squared_error: 0.8228 - val_y2_output_root_mean_squared_error: 1.3962
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3909 - y1_output_loss: 0.7735 - y2_output_loss: 2.6174 - y1_output_root_mean_squared_error: 0.8752 - y2_output_root_mean_squared_error: 1.6119 - val_loss: 5.6451 - val_y1_output_loss: 1.3111 - val_y2_output_loss: 4.3341 - val_y1_output_root_mean_squared_error: 1.1450 - val_y2_output_root_mean_squared_error: 2.0818
# Epoch 75/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.6808 - y1_output_loss: 1.9909 - y2_output_loss: 4.6899 - y1_output_root_mean_squared_error: 1.3728 - y2_output_root_mean_squared_error: 2.1332 - val_loss: 3.0364 - val_y1_output_loss: 0.6089 - val_y2_output_loss: 2.4274 - val_y1_output_root_mean_squared_error: 0.7804 - val_y2_output_root_mean_squared_error: 1.5580
# Epoch 76/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.4958 - y1_output_loss: 2.0421 - y2_output_loss: 5.4537 - y1_output_root_mean_squared_error: 1.3975 - y2_output_root_mean_squared_error: 2.2978 - val_loss: 2.6586 - val_y1_output_loss: 0.6711 - val_y2_output_loss: 1.9875 - val_y1_output_root_mean_squared_error: 0.8192 - val_y2_output_root_mean_squared_error: 1.4098
# Epoch 77/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.6208 - y1_output_loss: 0.6953 - y2_output_loss: 2.9255 - y1_output_root_mean_squared_error: 0.8330 - y2_output_root_mean_squared_error: 1.7038 - val_loss: 3.4774 - val_y1_output_loss: 0.8789 - val_y2_output_loss: 2.5985 - val_y1_output_root_mean_squared_error: 0.9375 - val_y2_output_root_mean_squared_error: 1.6120
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3980 - y1_output_loss: 0.8907 - y2_output_loss: 2.5073 - y1_output_root_mean_squared_error: 0.9398 - y2_output_root_mean_squared_error: 1.5791 - val_loss: 3.6817 - val_y1_output_loss: 0.7264 - val_y2_output_loss: 2.9553 - val_y1_output_root_mean_squared_error: 0.8523 - val_y2_output_root_mean_squared_error: 1.7191
# Epoch 79/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6297 - y1_output_loss: 0.5985 - y2_output_loss: 2.0313 - y1_output_root_mean_squared_error: 0.7721 - y2_output_root_mean_squared_error: 1.4213 - val_loss: 2.9718 - val_y1_output_loss: 0.6930 - val_y2_output_loss: 2.2788 - val_y1_output_root_mean_squared_error: 0.8325 - val_y2_output_root_mean_squared_error: 1.5096
# Epoch 80/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.0817 - y1_output_loss: 2.5562 - y2_output_loss: 5.5255 - y1_output_root_mean_squared_error: 1.5564 - y2_output_root_mean_squared_error: 2.3208 - val_loss: 3.6516 - val_y1_output_loss: 0.5896 - val_y2_output_loss: 3.0620 - val_y1_output_root_mean_squared_error: 0.7679 - val_y2_output_root_mean_squared_error: 1.7499
# Epoch 81/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9362 - y1_output_loss: 0.6632 - y2_output_loss: 2.2729 - y1_output_root_mean_squared_error: 0.8077 - y2_output_root_mean_squared_error: 1.5030 - val_loss: 2.7608 - val_y1_output_loss: 0.6044 - val_y2_output_loss: 2.1564 - val_y1_output_root_mean_squared_error: 0.7774 - val_y2_output_root_mean_squared_error: 1.4685
# Epoch 82/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0840 - y1_output_loss: 0.6904 - y2_output_loss: 2.3935 - y1_output_root_mean_squared_error: 0.8292 - y2_output_root_mean_squared_error: 1.5459 - val_loss: 3.6774 - val_y1_output_loss: 0.8336 - val_y2_output_loss: 2.8438 - val_y1_output_root_mean_squared_error: 0.9130 - val_y2_output_root_mean_squared_error: 1.6863
# Epoch 83/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7565 - y1_output_loss: 0.5919 - y2_output_loss: 2.1646 - y1_output_root_mean_squared_error: 0.7681 - y2_output_root_mean_squared_error: 1.4697 - val_loss: 2.6976 - val_y1_output_loss: 0.8995 - val_y2_output_loss: 1.7982 - val_y1_output_root_mean_squared_error: 0.9484 - val_y2_output_root_mean_squared_error: 1.3410
# Epoch 84/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8657 - y1_output_loss: 0.6439 - y2_output_loss: 2.2218 - y1_output_root_mean_squared_error: 0.7980 - y2_output_root_mean_squared_error: 1.4867 - val_loss: 2.5505 - val_y1_output_loss: 0.5889 - val_y2_output_loss: 1.9615 - val_y1_output_root_mean_squared_error: 0.7674 - val_y2_output_root_mean_squared_error: 1.4006
# Epoch 85/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6778 - y1_output_loss: 0.5372 - y2_output_loss: 2.1406 - y1_output_root_mean_squared_error: 0.7320 - y2_output_root_mean_squared_error: 1.4593 - val_loss: 2.2256 - val_y1_output_loss: 0.5422 - val_y2_output_loss: 1.6835 - val_y1_output_root_mean_squared_error: 0.7363 - val_y2_output_root_mean_squared_error: 1.2975
# Epoch 86/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7945 - y1_output_loss: 0.6399 - y2_output_loss: 2.1547 - y1_output_root_mean_squared_error: 0.7961 - y2_output_root_mean_squared_error: 1.4631 - val_loss: 9.5971 - val_y1_output_loss: 2.0785 - val_y2_output_loss: 7.5186 - val_y1_output_root_mean_squared_error: 1.4417 - val_y2_output_root_mean_squared_error: 2.7420
# Epoch 87/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.6464 - y1_output_loss: 0.8349 - y2_output_loss: 2.8116 - y1_output_root_mean_squared_error: 0.9095 - y2_output_root_mean_squared_error: 1.6744 - val_loss: 3.3825 - val_y1_output_loss: 0.8846 - val_y2_output_loss: 2.4979 - val_y1_output_root_mean_squared_error: 0.9405 - val_y2_output_root_mean_squared_error: 1.5805
# Epoch 88/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3225 - y1_output_loss: 1.1226 - y2_output_loss: 3.1999 - y1_output_root_mean_squared_error: 1.0569 - y2_output_root_mean_squared_error: 1.7857 - val_loss: 2.4105 - val_y1_output_loss: 0.5360 - val_y2_output_loss: 1.8745 - val_y1_output_root_mean_squared_error: 0.7321 - val_y2_output_root_mean_squared_error: 1.3691
# Epoch 89/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5044 - y1_output_loss: 0.6086 - y2_output_loss: 1.8958 - y1_output_root_mean_squared_error: 0.7780 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 9.6177 - val_y1_output_loss: 1.3114 - val_y2_output_loss: 8.3063 - val_y1_output_root_mean_squared_error: 1.1452 - val_y2_output_root_mean_squared_error: 2.8821
# Epoch 90/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7143 - y1_output_loss: 0.7292 - y2_output_loss: 2.9851 - y1_output_root_mean_squared_error: 0.8510 - y2_output_root_mean_squared_error: 1.7050 - val_loss: 3.2155 - val_y1_output_loss: 0.5315 - val_y2_output_loss: 2.6839 - val_y1_output_root_mean_squared_error: 0.7291 - val_y2_output_root_mean_squared_error: 1.6383
# Epoch 91/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0128 - y1_output_loss: 0.6561 - y2_output_loss: 2.3567 - y1_output_root_mean_squared_error: 0.7976 - y2_output_root_mean_squared_error: 1.5318 - val_loss: 3.6714 - val_y1_output_loss: 0.5812 - val_y2_output_loss: 3.0902 - val_y1_output_root_mean_squared_error: 0.7624 - val_y2_output_root_mean_squared_error: 1.7579
# Epoch 92/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.9120 - y1_output_loss: 0.8873 - y2_output_loss: 3.0247 - y1_output_root_mean_squared_error: 0.9322 - y2_output_root_mean_squared_error: 1.7241 - val_loss: 2.7484 - val_y1_output_loss: 0.6722 - val_y2_output_loss: 2.0762 - val_y1_output_root_mean_squared_error: 0.8199 - val_y2_output_root_mean_squared_error: 1.4409
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0859 - y1_output_loss: 0.6432 - y2_output_loss: 2.4427 - y1_output_root_mean_squared_error: 0.7995 - y2_output_root_mean_squared_error: 1.5586 - val_loss: 15.7539 - val_y1_output_loss: 5.0697 - val_y2_output_loss: 10.6842 - val_y1_output_root_mean_squared_error: 2.2516 - val_y2_output_root_mean_squared_error: 3.2687
# Epoch 94/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4684 - y1_output_loss: 1.1533 - y2_output_loss: 3.3151 - y1_output_root_mean_squared_error: 1.0612 - y2_output_root_mean_squared_error: 1.8071 - val_loss: 5.9476 - val_y1_output_loss: 0.9291 - val_y2_output_loss: 5.0186 - val_y1_output_root_mean_squared_error: 0.9639 - val_y2_output_root_mean_squared_error: 2.2402
# Epoch 95/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.5722 - y1_output_loss: 1.9086 - y2_output_loss: 3.6636 - y1_output_root_mean_squared_error: 1.3408 - y2_output_root_mean_squared_error: 1.8925 - val_loss: 2.3009 - val_y1_output_loss: 0.3917 - val_y2_output_loss: 1.9091 - val_y1_output_root_mean_squared_error: 0.6259 - val_y2_output_root_mean_squared_error: 1.3817
# Epoch 96/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9437 - y1_output_loss: 0.6659 - y2_output_loss: 2.2777 - y1_output_root_mean_squared_error: 0.8143 - y2_output_root_mean_squared_error: 1.5014 - val_loss: 3.2439 - val_y1_output_loss: 1.1309 - val_y2_output_loss: 2.1130 - val_y1_output_root_mean_squared_error: 1.0634 - val_y2_output_root_mean_squared_error: 1.4536
# Epoch 97/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6608 - y1_output_loss: 0.6671 - y2_output_loss: 1.9937 - y1_output_root_mean_squared_error: 0.8132 - y2_output_root_mean_squared_error: 1.4064 - val_loss: 1.9601 - val_y1_output_loss: 0.4720 - val_y2_output_loss: 1.4880 - val_y1_output_root_mean_squared_error: 0.6871 - val_y2_output_root_mean_squared_error: 1.2199
# Epoch 98/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6263 - y1_output_loss: 0.5321 - y2_output_loss: 2.0942 - y1_output_root_mean_squared_error: 0.7242 - y2_output_root_mean_squared_error: 1.4450 - val_loss: 2.8844 - val_y1_output_loss: 0.7330 - val_y2_output_loss: 2.1514 - val_y1_output_root_mean_squared_error: 0.8562 - val_y2_output_root_mean_squared_error: 1.4668
# Epoch 99/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.3855 - y1_output_loss: 1.1049 - y2_output_loss: 3.2806 - y1_output_root_mean_squared_error: 1.0414 - y2_output_root_mean_squared_error: 1.7958 - val_loss: 2.4731 - val_y1_output_loss: 0.5512 - val_y2_output_loss: 1.9219 - val_y1_output_root_mean_squared_error: 0.7424 - val_y2_output_root_mean_squared_error: 1.3863
# Epoch 100/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3932 - y1_output_loss: 0.5291 - y2_output_loss: 1.8640 - y1_output_root_mean_squared_error: 0.7271 - y2_output_root_mean_squared_error: 1.3643 - val_loss: 2.2630 - val_y1_output_loss: 0.4086 - val_y2_output_loss: 1.8544 - val_y1_output_root_mean_squared_error: 0.6392 - val_y2_output_root_mean_squared_error: 1.3618
# Epoch 101/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.2800 - y1_output_loss: 0.4935 - y2_output_loss: 1.7865 - y1_output_root_mean_squared_error: 0.7012 - y2_output_root_mean_squared_error: 1.3345 - val_loss: 7.0636 - val_y1_output_loss: 2.9034 - val_y2_output_loss: 4.1602 - val_y1_output_root_mean_squared_error: 1.7039 - val_y2_output_root_mean_squared_error: 2.0396
# Epoch 102/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9628 - y1_output_loss: 0.7703 - y2_output_loss: 2.1925 - y1_output_root_mean_squared_error: 0.8670 - y2_output_root_mean_squared_error: 1.4791 - val_loss: 2.1663 - val_y1_output_loss: 0.4419 - val_y2_output_loss: 1.7244 - val_y1_output_root_mean_squared_error: 0.6647 - val_y2_output_root_mean_squared_error: 1.3132
# Epoch 103/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2524 - y1_output_loss: 0.6858 - y2_output_loss: 2.5666 - y1_output_root_mean_squared_error: 0.8193 - y2_output_root_mean_squared_error: 1.5906 - val_loss: 5.5985 - val_y1_output_loss: 0.8521 - val_y2_output_loss: 4.7464 - val_y1_output_root_mean_squared_error: 0.9231 - val_y2_output_root_mean_squared_error: 2.1786
# Epoch 104/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5429 - y1_output_loss: 0.8623 - y2_output_loss: 2.6806 - y1_output_root_mean_squared_error: 0.9259 - y2_output_root_mean_squared_error: 1.6281 - val_loss: 2.4839 - val_y1_output_loss: 0.6058 - val_y2_output_loss: 1.8781 - val_y1_output_root_mean_squared_error: 0.7783 - val_y2_output_root_mean_squared_error: 1.3704
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9387 - y1_output_loss: 0.6308 - y2_output_loss: 2.3079 - y1_output_root_mean_squared_error: 0.7888 - y2_output_root_mean_squared_error: 1.5156 - val_loss: 2.9987 - val_y1_output_loss: 0.5791 - val_y2_output_loss: 2.4196 - val_y1_output_root_mean_squared_error: 0.7610 - val_y2_output_root_mean_squared_error: 1.5555
# Epoch 106/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1238 - y1_output_loss: 0.8866 - y2_output_loss: 2.2372 - y1_output_root_mean_squared_error: 0.9224 - y2_output_root_mean_squared_error: 1.4788 - val_loss: 2.1199 - val_y1_output_loss: 0.5130 - val_y2_output_loss: 1.6069 - val_y1_output_root_mean_squared_error: 0.7162 - val_y2_output_root_mean_squared_error: 1.2677
# Epoch 107/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7771 - y1_output_loss: 0.6450 - y2_output_loss: 2.1321 - y1_output_root_mean_squared_error: 0.7990 - y2_output_root_mean_squared_error: 1.4551 - val_loss: 8.5142 - val_y1_output_loss: 2.7889 - val_y2_output_loss: 5.7253 - val_y1_output_root_mean_squared_error: 1.6700 - val_y2_output_root_mean_squared_error: 2.3928
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.5882 - y1_output_loss: 2.0018 - y2_output_loss: 4.5864 - y1_output_root_mean_squared_error: 1.3786 - y2_output_root_mean_squared_error: 2.1223 - val_loss: 2.5707 - val_y1_output_loss: 0.4240 - val_y2_output_loss: 2.1467 - val_y1_output_root_mean_squared_error: 0.6512 - val_y2_output_root_mean_squared_error: 1.4651
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7984 - y1_output_loss: 0.5741 - y2_output_loss: 2.2242 - y1_output_root_mean_squared_error: 0.7494 - y2_output_root_mean_squared_error: 1.4837 - val_loss: 2.1740 - val_y1_output_loss: 0.4950 - val_y2_output_loss: 1.6790 - val_y1_output_root_mean_squared_error: 0.7036 - val_y2_output_root_mean_squared_error: 1.2958
# Epoch 110/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8996 - y1_output_loss: 0.8264 - y2_output_loss: 2.0732 - y1_output_root_mean_squared_error: 0.9061 - y2_output_root_mean_squared_error: 1.4364 - val_loss: 3.0808 - val_y1_output_loss: 0.8304 - val_y2_output_loss: 2.2504 - val_y1_output_root_mean_squared_error: 0.9112 - val_y2_output_root_mean_squared_error: 1.5001
# Epoch 111/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.4595 - y1_output_loss: 0.9060 - y2_output_loss: 2.5535 - y1_output_root_mean_squared_error: 0.9360 - y2_output_root_mean_squared_error: 1.5818 - val_loss: 3.6000 - val_y1_output_loss: 0.4826 - val_y2_output_loss: 3.1174 - val_y1_output_root_mean_squared_error: 0.6947 - val_y2_output_root_mean_squared_error: 1.7656
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.4830 - y1_output_loss: 0.5200 - y2_output_loss: 1.9630 - y1_output_root_mean_squared_error: 0.7202 - y2_output_root_mean_squared_error: 1.3972 - val_loss: 4.8005 - val_y1_output_loss: 1.3721 - val_y2_output_loss: 3.4285 - val_y1_output_root_mean_squared_error: 1.1713 - val_y2_output_root_mean_squared_error: 1.8516
# Epoch 113/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7030 - y1_output_loss: 1.3468 - y2_output_loss: 3.3562 - y1_output_root_mean_squared_error: 1.1490 - y2_output_root_mean_squared_error: 1.8244 - val_loss: 2.4259 - val_y1_output_loss: 0.6705 - val_y2_output_loss: 1.7554 - val_y1_output_root_mean_squared_error: 0.8188 - val_y2_output_root_mean_squared_error: 1.3249
# Epoch 114/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9694 - y1_output_loss: 0.6367 - y2_output_loss: 2.3328 - y1_output_root_mean_squared_error: 0.7931 - y2_output_root_mean_squared_error: 1.5114 - val_loss: 4.7970 - val_y1_output_loss: 1.1052 - val_y2_output_loss: 3.6917 - val_y1_output_root_mean_squared_error: 1.0513 - val_y2_output_root_mean_squared_error: 1.9214
# Epoch 115/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0519 - y1_output_loss: 0.6765 - y2_output_loss: 2.3754 - y1_output_root_mean_squared_error: 0.8169 - y2_output_root_mean_squared_error: 1.5315 - val_loss: 3.3919 - val_y1_output_loss: 0.4939 - val_y2_output_loss: 2.8980 - val_y1_output_root_mean_squared_error: 0.7028 - val_y2_output_root_mean_squared_error: 1.7024
# Epoch 116/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3509 - y1_output_loss: 0.4504 - y2_output_loss: 1.9004 - y1_output_root_mean_squared_error: 0.6701 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 2.0616 - val_y1_output_loss: 0.5904 - val_y2_output_loss: 1.4712 - val_y1_output_root_mean_squared_error: 0.7684 - val_y2_output_root_mean_squared_error: 1.2129
# Epoch 117/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.2688 - y1_output_loss: 0.5684 - y2_output_loss: 1.7004 - y1_output_root_mean_squared_error: 0.7521 - y2_output_root_mean_squared_error: 1.2939 - val_loss: 1.7280 - val_y1_output_loss: 0.3234 - val_y2_output_loss: 1.4046 - val_y1_output_root_mean_squared_error: 0.5687 - val_y2_output_root_mean_squared_error: 1.1852
# Epoch 118/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.1721 - y1_output_loss: 0.4659 - y2_output_loss: 1.7062 - y1_output_root_mean_squared_error: 0.6819 - y2_output_root_mean_squared_error: 1.3021 - val_loss: 3.9220 - val_y1_output_loss: 0.8515 - val_y2_output_loss: 3.0706 - val_y1_output_root_mean_squared_error: 0.9227 - val_y2_output_root_mean_squared_error: 1.7523
# Epoch 119/500
# 62/62 [==============================] - 0s 2ms/step - loss: 1.9870 - y1_output_loss: 0.3965 - y2_output_loss: 1.5905 - y1_output_root_mean_squared_error: 0.6269 - y2_output_root_mean_squared_error: 1.2589 - val_loss: 5.3358 - val_y1_output_loss: 1.9822 - val_y2_output_loss: 3.3536 - val_y1_output_root_mean_squared_error: 1.4079 - val_y2_output_root_mean_squared_error: 1.8313
# Epoch 120/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8266 - y1_output_loss: 0.8885 - y2_output_loss: 2.9382 - y1_output_root_mean_squared_error: 0.9390 - y2_output_root_mean_squared_error: 1.7070 - val_loss: 2.7667 - val_y1_output_loss: 0.4240 - val_y2_output_loss: 2.3427 - val_y1_output_root_mean_squared_error: 0.6512 - val_y2_output_root_mean_squared_error: 1.5306
# Epoch 121/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.2467 - y1_output_loss: 0.4607 - y2_output_loss: 1.7859 - y1_output_root_mean_squared_error: 0.6756 - y2_output_root_mean_squared_error: 1.3341 - val_loss: 3.2151 - val_y1_output_loss: 0.5488 - val_y2_output_loss: 2.6663 - val_y1_output_root_mean_squared_error: 0.7408 - val_y2_output_root_mean_squared_error: 1.6329
# Epoch 122/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.0043 - y1_output_loss: 0.4186 - y2_output_loss: 1.5857 - y1_output_root_mean_squared_error: 0.6463 - y2_output_root_mean_squared_error: 1.2567 - val_loss: 2.8089 - val_y1_output_loss: 0.5845 - val_y2_output_loss: 2.2243 - val_y1_output_root_mean_squared_error: 0.7645 - val_y2_output_root_mean_squared_error: 1.4914
# Epoch 123/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3751 - y1_output_loss: 0.1270 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.4916 - val_loss: 0.7815 - val_y1_output_loss: 0.2263 - val_y2_output_loss: 0.5552 - val_y1_output_root_mean_squared_error: 0.4758 - val_y2_output_root_mean_squared_error: 0.7451
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4316 - y1_output_loss: 0.1409 - y2_output_loss: 0.2907 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.5366 - val_loss: 0.6857 - val_y1_output_loss: 0.1307 - val_y2_output_loss: 0.5550 - val_y1_output_root_mean_squared_error: 0.3615 - val_y2_output_root_mean_squared_error: 0.7450
# Epoch 463/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3700 - y1_output_loss: 0.1057 - y2_output_loss: 0.2644 - y1_output_root_mean_squared_error: 0.3219 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.7144 - val_y1_output_loss: 0.2041 - val_y2_output_loss: 0.5103 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.7144
# Epoch 464/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4662 - y1_output_loss: 0.1526 - y2_output_loss: 0.3136 - y1_output_root_mean_squared_error: 0.3897 - y2_output_root_mean_squared_error: 0.5578 - val_loss: 0.6527 - val_y1_output_loss: 0.1431 - val_y2_output_loss: 0.5096 - val_y1_output_root_mean_squared_error: 0.3783 - val_y2_output_root_mean_squared_error: 0.7138
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5295 - y1_output_loss: 0.1515 - y2_output_loss: 0.3781 - y1_output_root_mean_squared_error: 0.3796 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 0.5396 - val_y1_output_loss: 0.1341 - val_y2_output_loss: 0.4055 - val_y1_output_root_mean_squared_error: 0.3662 - val_y2_output_root_mean_squared_error: 0.6368
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2986 - y1_output_loss: 0.1069 - y2_output_loss: 0.1917 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.4370 - val_loss: 2.7278 - val_y1_output_loss: 0.5687 - val_y2_output_loss: 2.1591 - val_y1_output_root_mean_squared_error: 0.7541 - val_y2_output_root_mean_squared_error: 1.4694
# Epoch 467/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8778 - y1_output_loss: 0.2115 - y2_output_loss: 0.6663 - y1_output_root_mean_squared_error: 0.4567 - y2_output_root_mean_squared_error: 0.8012 - val_loss: 1.5015 - val_y1_output_loss: 0.1298 - val_y2_output_loss: 1.3717 - val_y1_output_root_mean_squared_error: 0.3603 - val_y2_output_root_mean_squared_error: 1.1712
# Epoch 468/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5166 - y1_output_loss: 0.1297 - y2_output_loss: 0.3869 - y1_output_root_mean_squared_error: 0.3594 - y2_output_root_mean_squared_error: 0.6173 - val_loss: 0.5766 - val_y1_output_loss: 0.1525 - val_y2_output_loss: 0.4241 - val_y1_output_root_mean_squared_error: 0.3905 - val_y2_output_root_mean_squared_error: 0.6513
# Epoch 469/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3708 - y1_output_loss: 0.1156 - y2_output_loss: 0.2552 - y1_output_root_mean_squared_error: 0.3391 - y2_output_root_mean_squared_error: 0.5041 - val_loss: 0.5357 - val_y1_output_loss: 0.1154 - val_y2_output_loss: 0.4202 - val_y1_output_root_mean_squared_error: 0.3398 - val_y2_output_root_mean_squared_error: 0.6483
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4018 - y1_output_loss: 0.1352 - y2_output_loss: 0.2666 - y1_output_root_mean_squared_error: 0.3674 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.1492 - val_y1_output_loss: 0.1470 - val_y2_output_loss: 1.0022 - val_y1_output_root_mean_squared_error: 0.3834 - val_y2_output_root_mean_squared_error: 1.0011
# Epoch 471/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6796 - y1_output_loss: 0.1580 - y2_output_loss: 0.5216 - y1_output_root_mean_squared_error: 0.3941 - y2_output_root_mean_squared_error: 0.6988 - val_loss: 0.4960 - val_y1_output_loss: 0.1060 - val_y2_output_loss: 0.3900 - val_y1_output_root_mean_squared_error: 0.3256 - val_y2_output_root_mean_squared_error: 0.6245
# Epoch 472/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4230 - y1_output_loss: 0.1395 - y2_output_loss: 0.2835 - y1_output_root_mean_squared_error: 0.3727 - y2_output_root_mean_squared_error: 0.5297 - val_loss: 1.2046 - val_y1_output_loss: 0.1257 - val_y2_output_loss: 1.0788 - val_y1_output_root_mean_squared_error: 0.3546 - val_y2_output_root_mean_squared_error: 1.0387
# Epoch 473/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5205 - y1_output_loss: 0.1353 - y2_output_loss: 0.3852 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.6086 - val_loss: 0.5131 - val_y1_output_loss: 0.1270 - val_y2_output_loss: 0.3861 - val_y1_output_root_mean_squared_error: 0.3564 - val_y2_output_root_mean_squared_error: 0.6213
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3624 - y1_output_loss: 0.1156 - y2_output_loss: 0.2469 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4961 - val_loss: 0.5226 - val_y1_output_loss: 0.1245 - val_y2_output_loss: 0.3981 - val_y1_output_root_mean_squared_error: 0.3529 - val_y2_output_root_mean_squared_error: 0.6309
# Epoch 475/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3123 - y1_output_loss: 0.1263 - y2_output_loss: 0.1860 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.4288 - val_loss: 0.5060 - val_y1_output_loss: 0.1114 - val_y2_output_loss: 0.3946 - val_y1_output_root_mean_squared_error: 0.3338 - val_y2_output_root_mean_squared_error: 0.6282
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4144 - y1_output_loss: 0.1421 - y2_output_loss: 0.2723 - y1_output_root_mean_squared_error: 0.3746 - y2_output_root_mean_squared_error: 0.5195 - val_loss: 0.5444 - val_y1_output_loss: 0.1165 - val_y2_output_loss: 0.4279 - val_y1_output_root_mean_squared_error: 0.3414 - val_y2_output_root_mean_squared_error: 0.6541
# Epoch 477/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5231 - y1_output_loss: 0.1370 - y2_output_loss: 0.3861 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.6153 - val_loss: 0.5552 - val_y1_output_loss: 0.1291 - val_y2_output_loss: 0.4261 - val_y1_output_root_mean_squared_error: 0.3593 - val_y2_output_root_mean_squared_error: 0.6528
# Epoch 478/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4454 - y1_output_loss: 0.1638 - y2_output_loss: 0.2816 - y1_output_root_mean_squared_error: 0.4031 - y2_output_root_mean_squared_error: 0.5292 - val_loss: 1.2481 - val_y1_output_loss: 0.2708 - val_y2_output_loss: 0.9773 - val_y1_output_root_mean_squared_error: 0.5204 - val_y2_output_root_mean_squared_error: 0.9886
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5871 - y1_output_loss: 0.1783 - y2_output_loss: 0.4088 - y1_output_root_mean_squared_error: 0.4120 - y2_output_root_mean_squared_error: 0.6234 - val_loss: 0.7599 - val_y1_output_loss: 0.2682 - val_y2_output_loss: 0.4918 - val_y1_output_root_mean_squared_error: 0.5178 - val_y2_output_root_mean_squared_error: 0.7013
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3978 - y1_output_loss: 0.1417 - y2_output_loss: 0.2562 - y1_output_root_mean_squared_error: 0.3728 - y2_output_root_mean_squared_error: 0.5046 - val_loss: 0.6450 - val_y1_output_loss: 0.1328 - val_y2_output_loss: 0.5122 - val_y1_output_root_mean_squared_error: 0.3645 - val_y2_output_root_mean_squared_error: 0.7157
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4274 - y1_output_loss: 0.1220 - y2_output_loss: 0.3054 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.5513 - val_loss: 0.6684 - val_y1_output_loss: 0.1115 - val_y2_output_loss: 0.5569 - val_y1_output_root_mean_squared_error: 0.3340 - val_y2_output_root_mean_squared_error: 0.7462
# Epoch 482/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3143 - y1_output_loss: 0.1151 - y2_output_loss: 0.1991 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.4455 - val_loss: 0.5754 - val_y1_output_loss: 0.1230 - val_y2_output_loss: 0.4524 - val_y1_output_root_mean_squared_error: 0.3507 - val_y2_output_root_mean_squared_error: 0.6726
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4145 - y1_output_loss: 0.1516 - y2_output_loss: 0.2629 - y1_output_root_mean_squared_error: 0.3890 - y2_output_root_mean_squared_error: 0.5097 - val_loss: 0.6638 - val_y1_output_loss: 0.1438 - val_y2_output_loss: 0.5199 - val_y1_output_root_mean_squared_error: 0.3793 - val_y2_output_root_mean_squared_error: 0.7211
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5077 - y1_output_loss: 0.1767 - y2_output_loss: 0.3310 - y1_output_root_mean_squared_error: 0.4193 - y2_output_root_mean_squared_error: 0.5731 - val_loss: 1.2060 - val_y1_output_loss: 0.2776 - val_y2_output_loss: 0.9285 - val_y1_output_root_mean_squared_error: 0.5268 - val_y2_output_root_mean_squared_error: 0.9636
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4445 - y1_output_loss: 0.1556 - y2_output_loss: 0.2889 - y1_output_root_mean_squared_error: 0.3931 - y2_output_root_mean_squared_error: 0.5340 - val_loss: 0.4393 - val_y1_output_loss: 0.1010 - val_y2_output_loss: 0.3383 - val_y1_output_root_mean_squared_error: 0.3178 - val_y2_output_root_mean_squared_error: 0.5817
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3032 - y1_output_loss: 0.1051 - y2_output_loss: 0.1981 - y1_output_root_mean_squared_error: 0.3231 - y2_output_root_mean_squared_error: 0.4424 - val_loss: 0.5000 - val_y1_output_loss: 0.1022 - val_y2_output_loss: 0.3978 - val_y1_output_root_mean_squared_error: 0.3197 - val_y2_output_root_mean_squared_error: 0.6307
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3945 - y1_output_loss: 0.1455 - y2_output_loss: 0.2490 - y1_output_root_mean_squared_error: 0.3792 - y2_output_root_mean_squared_error: 0.4941 - val_loss: 0.6517 - val_y1_output_loss: 0.1891 - val_y2_output_loss: 0.4626 - val_y1_output_root_mean_squared_error: 0.4349 - val_y2_output_root_mean_squared_error: 0.6801
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4004 - y1_output_loss: 0.1332 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.5151 - val_loss: 1.6503 - val_y1_output_loss: 0.3451 - val_y2_output_loss: 1.3052 - val_y1_output_root_mean_squared_error: 0.5875 - val_y2_output_root_mean_squared_error: 1.1425
# Epoch 489/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4359 - y1_output_loss: 0.1418 - y2_output_loss: 0.2941 - y1_output_root_mean_squared_error: 0.3747 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 0.5775 - val_y1_output_loss: 0.1411 - val_y2_output_loss: 0.4364 - val_y1_output_root_mean_squared_error: 0.3757 - val_y2_output_root_mean_squared_error: 0.6606
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3799 - y1_output_loss: 0.1291 - y2_output_loss: 0.2508 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.4993 - val_loss: 0.6829 - val_y1_output_loss: 0.1386 - val_y2_output_loss: 0.5443 - val_y1_output_root_mean_squared_error: 0.3723 - val_y2_output_root_mean_squared_error: 0.7378
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4563 - y1_output_loss: 0.1482 - y2_output_loss: 0.3081 - y1_output_root_mean_squared_error: 0.3835 - y2_output_root_mean_squared_error: 0.5515 - val_loss: 0.7162 - val_y1_output_loss: 0.1875 - val_y2_output_loss: 0.5286 - val_y1_output_root_mean_squared_error: 0.4331 - val_y2_output_root_mean_squared_error: 0.7271
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3733 - y1_output_loss: 0.1280 - y2_output_loss: 0.2453 - y1_output_root_mean_squared_error: 0.3570 - y2_output_root_mean_squared_error: 0.4945 - val_loss: 0.5536 - val_y1_output_loss: 0.1587 - val_y2_output_loss: 0.3949 - val_y1_output_root_mean_squared_error: 0.3984 - val_y2_output_root_mean_squared_error: 0.6284
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3210 - y1_output_loss: 0.1221 - y2_output_loss: 0.1989 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.4456 - val_loss: 0.4307 - val_y1_output_loss: 0.0995 - val_y2_output_loss: 0.3311 - val_y1_output_root_mean_squared_error: 0.3155 - val_y2_output_root_mean_squared_error: 0.5754
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3575 - y1_output_loss: 0.1384 - y2_output_loss: 0.2191 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.4675 - val_loss: 0.9162 - val_y1_output_loss: 0.1163 - val_y2_output_loss: 0.7999 - val_y1_output_root_mean_squared_error: 0.3410 - val_y2_output_root_mean_squared_error: 0.8944
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6238 - y1_output_loss: 0.1624 - y2_output_loss: 0.4613 - y1_output_root_mean_squared_error: 0.4024 - y2_output_root_mean_squared_error: 0.6707 - val_loss: 0.4678 - val_y1_output_loss: 0.1009 - val_y2_output_loss: 0.3669 - val_y1_output_root_mean_squared_error: 0.3177 - val_y2_output_root_mean_squared_error: 0.6057
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3322 - y1_output_loss: 0.1109 - y2_output_loss: 0.2213 - y1_output_root_mean_squared_error: 0.3323 - y2_output_root_mean_squared_error: 0.4690 - val_loss: 0.5158 - val_y1_output_loss: 0.1235 - val_y2_output_loss: 0.3923 - val_y1_output_root_mean_squared_error: 0.3514 - val_y2_output_root_mean_squared_error: 0.6264
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4136 - y1_output_loss: 0.1277 - y2_output_loss: 0.2858 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.5179 - val_loss: 0.5711 - val_y1_output_loss: 0.1097 - val_y2_output_loss: 0.4614 - val_y1_output_root_mean_squared_error: 0.3312 - val_y2_output_root_mean_squared_error: 0.6793
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3562 - y1_output_loss: 0.1272 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.4770 - val_loss: 0.5195 - val_y1_output_loss: 0.1392 - val_y2_output_loss: 0.3803 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.6167
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3321 - y1_output_loss: 0.1523 - y2_output_loss: 0.1798 - y1_output_root_mean_squared_error: 0.3854 - y2_output_root_mean_squared_error: 0.4215 - val_loss: 0.5752 - val_y1_output_loss: 0.1259 - val_y2_output_loss: 0.4493 - val_y1_output_root_mean_squared_error: 0.3548 - val_y2_output_root_mean_squared_error: 0.6703
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2701 - y1_output_loss: 0.1199 - y2_output_loss: 0.1502 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.3865 - val_loss: 2.0267 - val_y1_output_loss: 0.3726 - val_y2_output_loss: 1.6541 - val_y1_output_root_mean_squared_error: 0.6104 - val_y2_output_root_mean_squared_error: 1.2861

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 2.0267 - y1_output_loss: 0.3726 - y2_output_loss: 1.6541 - y1_output_root_mean_squared_error: 0.6104 - y2_output_root_mean_squared_error: 1.2861
# Loss = 2.0267293453216553, Y1_loss = 0.3726208806037903, Y1_mse = 0.6104267835617065, Y2_loss = 1.6541087627410889, Y2_mse = 1.2861216068267822

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
